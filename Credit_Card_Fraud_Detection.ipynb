# %%
# importing libraries

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the dataset
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# **Handling Missing Values**

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# We can see there are no Null Values

# %% [markdown]
# **Checking the distribution of Classes**

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# %age distribution
df['Class'].value_counts(normalize = True)*100
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: proportion, dtype: float64

# %% [markdown]
# 0 - **Non-Fradulant**
# 1 - **Fraudulant**
#
# ***Interpretation***:
# There exist a problem of **Class Imbalance**

# %% [markdown]
# **Visualizing** **Graphically**

# %%
# Calculate class distribution percentages
class_dist = df['Class'].value_counts(normalize=True) * 100

# Plot bar chart
ax = class_dist.plot(kind='bar', color=['g', 'r'])

# Add percentage labels
ax.bar_label(ax.containers[0], labels=[f'{v:.2f}%' for v in class_dist], label_type='edge')

# Customize chart
ax.set_title('Percentage Distribution of Classes')
ax.set_xlabel('Class')
ax.set_ylabel('Percentage')

plt.show()

# %% [markdown]
# **Outliers treatment**

# %% [markdown]
# We are not applying any outlier treatment to this dataset since all the features have already been PCA-transformed, and the transformation process inherently accounts for potential outlier effects.

# %% [markdown]
# **Distribution of classes with time**

# %%
# creating fradulant dataframes
data_fraud = df[df['Class'] == 1]

# Creating non fraudulent dataframe
data_non_fraud = df[df['Class'] == 0]

print(data_fraud.shape)
print(data_non_fraud.shape)
# Out:
# (492, 31)
# (284315, 31)

# %%
# Distribution plot of transaction time
plt.figure(figsize=(8, 5))

sns.kdeplot(data=data_fraud['Time'], label='Fraudulent', fill=False)
sns.kdeplot(data=data_non_fraud['Time'], label='Non-Fraudulent', fill=False)

plt.xlabel('Seconds elapsed between the transaction and the first transaction')
plt.ylabel('Density')
plt.title('Distribution of Transaction Time')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Interpretation**
# We do not see any specific pattern for the fraudulent and non-fraudulent transctions with respect to Time. Hence, we can drop the Time column.

# %%
# dropping the Time column
df.drop('Time', axis=1, inplace=True)

# %%
# validating the dataframe
df.shape
# Out:
# (284807, 30)

# %% [markdown]
# **Distribution of classes with amount**

# %%
df[df.Class==1].Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Distribution of fraudulent transaction amounts
plt.figure(figsize=(10, 5))

sns.histplot(data=data_fraud['Amount'], bins=50, kde=False, color='r')

plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')
plt.title('Distribution of Fraudulent Transaction Amounts')
plt.xticks(range(0, 2500, 100), rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretation:**
#
# - The majority of fraudulent transactions occur within the low-value range of 0–50 dollars, indicating that small amounts are more commonly targeted.
#
# - The largest fraudulent transaction observed falls within the range of 2100–2150 dollars, showing that while rare, high-value frauds do exist.

# %% [markdown]
# **Train-Test Split**

# %%
# import library

from sklearn.model_selection import train_test_split

# %%
# putting all features in X
X = df.drop(['Class'], axis=1)

# %%
# assigning target variable to y
y = df['Class']

# %%
# validating the X
X.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Amount
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
#
# [5 rows x 29 columns]

# %%
# validating the assignment
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.70, stratify=y, random_state=42)

# %% [markdown]
# **Feature Scaling**

# %% [markdown]
# We need to scale only the Amount column as all other columns are already scaled by the PCA transformation.

# %%
# importing the library for Standardization
from sklearn.preprocessing import StandardScaler

# %%
# Instantiate the Scaler
scaler = StandardScaler()

# %%
X_train['Amount'] = scaler.fit_transform(X_train[['Amount']])

# %%
X_train.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 249927 -0.012102  0.707332  0.163334 -0.756498  0.590999 -0.653429  0.844608
# 214082  1.776151 -0.184642 -2.204096  1.191668  0.614461 -1.016525  0.919254
# 106005 -1.083391 -4.440527 -1.399530  0.469764 -2.076458 -0.766137  1.601441
# 58619  -0.518847  1.025087 -0.614624 -0.780959  2.474666  3.335055  0.046111
# 191638 -0.640421  0.212171  0.283341 -1.786916  2.616127  4.024863 -0.198897
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 249927 -0.001672 -0.184399 -0.222719  ... -0.038329 -0.231385 -0.572415
# 214082 -0.387465 -0.318277  0.517022  ... -0.030437  0.281190  0.530070
# 106005 -0.709176 -1.288745  0.086419  ...  2.189260  0.346463 -1.432833
# 58619   0.794249 -0.322448  0.128383  ...  0.225957 -0.193099 -0.708348
# 191638  0.937087  0.474428 -0.283699  ...  0.154309  0.167939  0.759218
#
#              V23       V24       V25       V26       V27       V28    Amount
# 249927  0.042660 -0.360882 -0.494703  0.142657  0.235922  0.083758 -0.321082
# 214082 -0.232262 -0.342096  0.492355 -0.427682 -0.075228 -0.056755  0.243475
# 106005 -1.097063  0.505926 -0.140185  0.870190 -0.316982  0.227833  4.797594
# 58619   0.145672  0.944217 -0.788017  0.039995  0.010804  0.254309 -0.331514
# 191638 -0.321412  0.767971 -0.084221  0.612936  0.074029 -0.033344 -0.331514
#
# [5 rows x 29 columns]

# %% [markdown]
# **Scaling the test set**

# %%
# transform the test set

X_test['Amount'] = scaler.transform(X_test[['Amount']])
X_test.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 186882 -2.537331  1.890864 -0.840555 -1.102759 -2.105725  0.367811 -2.737844
# 165754 -0.250839  1.104108  0.206089  0.417324  1.204079 -0.350694  1.369769
# 235285  0.568980 -2.520416 -1.114138  1.670652 -1.128945  0.398822  0.190403
# 101271  1.328892  0.226908 -0.308968  0.381772  0.238490 -0.282946  0.029460
# 5832    1.124863 -0.165691  1.337053  1.030033 -0.891116  0.202926 -0.825094
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 186882 -3.543314 -0.483147  0.112724  ... -1.959611  4.328165 -2.167329
# 165754 -0.133535 -0.957100 -0.261170  ... -0.128120  0.133048  0.499501
# 235285  0.161493  0.840595  0.099172  ...  1.039287  0.318037 -0.760732
# 101271 -0.079962  0.227173 -0.267319  ... -0.050933 -0.379270 -1.148959
# 5832    0.163280  2.301808 -0.641129  ... -0.196966 -0.216512 -0.195607
#
#              V23       V24       V25       V26       V27       V28    Amount
# 186882  1.022567 -0.241143 -1.094885 -0.475427 -0.177157 -0.082691 -0.201469
# 165754 -0.392572 -0.393364  0.233354 -0.490717  0.143897  0.136810 -0.312626
# 235285 -0.181332  0.595866 -0.760920 -1.048927 -0.096970  0.088686  2.416826
# 101271 -0.047403 -1.074464  0.375683  0.182045 -0.031732  0.017501 -0.290023
# 5832    0.072785  0.045625  0.135192  0.308617  0.001142  0.017673 -0.281092
#
# [5 rows x 29 columns]

# %% [markdown]
# **Checking the Skewness**

# %%
# listing all columns
cols = X_train.columns
cols
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
#       dtype='object')

# %%
# Plotting the distribution and skewness of all variables
plt.figure(figsize=(12, 20))

for i, col in enumerate(cols, 1):
    plt.subplot(6, 5, i)
    sns.histplot(X_train[col], kde=True)
    plt.title(f"{col} → Skewness: {X_train[col].skew():.3f}")
    plt.tight_layout()

plt.show()

# %% [markdown]
# - Several variables exhibit significant skewness in their distributions.
# - To address this, we will apply transformations to reduce skewness and bring the variables closer to a normal distribution.

# %% [markdown]
# **Mitigate skweness with PowerTransformer**

# %%
# Importing PowerTransformer
from sklearn.preprocessing import PowerTransformer 

# Instantiate the powertransformer
pt = PowerTransformer(method='yeo-johnson', standardize=True, copy=False)

# Fit and transform the PT on training data
X_train[cols] = pt.fit_transform(X_train)

# %%
# Transform the test set
X_test = pt.transform(X_test)

# %%
# Now Validating the distribution of the variables (skewness) of all the columns

# Plotting the distribution and skewness of all variables
plt.figure(figsize=(12, 20))

for i, col in enumerate(cols, 1):
    plt.subplot(6, 5, i)
    sns.histplot(X_train[col], kde=True)
    plt.title(f"{col} → Skewness: {X_train[col].skew():.3f}")
    plt.tight_layout()

plt.show()

# %% [markdown]
# - Now we can see that all the variables seem to be normallly distributed after transformation

# %% [markdown]
# ## **Model building on imbalanced data**

# %% [markdown]
# **Metric selection for heavily imbalanced data. Here are some Noteworthy points to be discussed.**

# %% [markdown]
# - The dataset is **heavily imbalanced**, with only about **0.17% of transactions being fraudulent**.
#   Therefore, **accuracy** is not a reliable metric for evaluating the model.
#
# - For instance, if a model predicts the same class (all `0`s or all `1`s) for every data point, it would still achieve an accuracy of over **99%**, while completely failing to detect fraud.
#
# - To fairly evaluate the model, we use the **ROC-AUC score**, which considers performance across all classification thresholds.
#
# - In other words, **accuracy alone is misleading** in imbalanced datasets, as it does not capture the model's ability to correctly identify the **minority class**.
#
# - The **ROC curve** helps us assess the model’s performance across thresholds. It shows the trade-off between **True Positive Rate (TPR)** and **False Positive Rate (FPR)**.
#
# - The default decision threshold of **0.5** is not always optimal.
#   - The best threshold is typically the one where **TPR is high** and **FPR is low**, minimizing misclassifications.
#
# - Once the **optimal threshold** is chosen, we can compute the **F1 score**, which balances **precision** and **recall**, to better measure the classifier’s effectiveness at that threshold.

# %% [markdown]
# **Why SVM (and in some cases Random Forest) was not used for model building?**
#
# - The dataset contains **284,807 data points**, and after applying **oversampling**, the size becomes even larger.
# - **Support Vector Machines (SVMs)** are not efficient on very large datasets since they require substantial **computational power** and **memory** to perform the transformations.
# - Performing **K-Fold Cross Validation** for hyperparameter tuning further increases the computational cost and becomes extremely **time-consuming**.
# - Due to these **resource and time constraints**, SVM was not considered for this problem.
#
# - Similarly, in a few cases, **Random Forest** was also avoided because training multiple deep decision trees on such a large dataset with cross-validation can be computationally expensive and slow.

# %% [markdown]
# **Why KNN was not used for model building?**
#
# - **K-Nearest Neighbors (KNN)** is not memory efficient, as the algorithm needs to **store all data points** during training.
# - As the dataset size increases, KNN becomes **very slow**, since for every new data point it must compute the **distance to all other points** in the dataset to find the nearest neighbors.
# - This makes KNN **computationally expensive** and impractical for large datasets like ours.

# %% [markdown]
# **Logistic regression**

# %%
# importing the logistic regression module
from sklearn.linear_model import LogisticRegression

# %%
# importing metrics
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report

# %% [markdown]
# **Tuning Hyperparameter (C in Regularization)**
#
# - **Regularization** is used to prevent overfitting by adding a **penalty term** to the loss function, discouraging the model from becoming overly complex and fitting the training data too closely.
#
# - The hyperparameter **C** controls the strength of regularization:
#   - **Smaller C** → Stronger regularization
#     - The model is more constrained, leading to **simpler decision boundaries**.
#     - Helps reduce overfitting, but if too small, it can cause **underfitting**.
#   - **Larger C** → Weaker regularization
#     - The model fits the training data more closely.
#     - May improve training performance, but increases the risk of **overfitting**.

# %%
# Importing libraries for cross validation
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
# Creating KFold object with 5 splits
folds = KFold(n_splits=5, random_state=4, shuffle=True)

# specify params
params = {'C': [0.01, 0.1, 1, 10, 100, 1000]}

# Specifing score as recall as we are more focused on acheiving the higher sensitivity than the accuracy
model_cv = GridSearchCV(estimator = LogisticRegression(), 
                        param_grid = params, 
                        scoring ='roc_auc', 
                        cv=folds, 
                        verbose=1, 
                        return_train_score=True)

# %%
# fit the model
model_cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=4, shuffle=True),
#              estimator=LogisticRegression(),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100, 1000]},
#              return_train_score=True, scoring='roc_auc', verbose=1)

# %%
# results of GridSearchCV
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.170574      0.021645         0.017256        0.004712    0.01
# 1       0.176998      0.032682         0.016067        0.012941     0.1
# 2       0.158372      0.013786         0.012412        0.003992       1
# 3       0.186886      0.023988         0.012736        0.004284      10
# 4       0.184117      0.024411         0.014161        0.002145     100
# 5       0.179354      0.014324         0.011865        0.003333    1000
#
#         params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'C': 0.01}           0.995050           0.983371           0.971249
# 1   {'C': 0.1}           0.993721           0.980232           0.971985
# 2     {'C': 1}           0.993457           0.978480           0.971715
# 3    {'C': 10}           0.993006           0.978572           0.971682
# 4   {'C': 100}           0.992999           0.978348           0.971675
# 5  {'C': 1000}           0.992998           0.978326           0.971676
#
#    split3_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# 0           0.993282  ...         0.983678        0.009423                6
# 1           0.994488  ...         0.984291        0.008619                1
# 2           0.994525  ...         0.983977        0.008796                5
# 3           0.995144  ...         0.984034        0.008848                2
# 4           0.995155  ...         0.983991        0.008879                3
# 5           0.995156  ...         0.983987        0.008882                4
#
#    split0_train_score  split1_train_score  split2_train_score  \
# 0            0.984088            0.988340            0.990640
# 1            0.984749            0.988714            0.990128
# 2            0.984766            0.988481            0.989782
# 3            0.985092            0.988511            0.989739
# 4            0.985092            0.988458            0.989733
# 5            0.985092            0.988453            0.989733
#
#    split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0            0.985158            0.986584          0.986962         0.002328
# 1            0.984745            0.985910          0.986849         0.002189
# 2            0.984468            0.985555          0.986610         0.002129
# 3            0.983985            0.985511          0.986568         0.002182
# 4            0.983978            0.985507          0.986554         0.002173
# 5            0.983977            0.985507          0.986552         0.002172
#
# [6 rows x 21 columns]

# %%
cv_results[['params', 'mean_test_score', 'std_test_score', 'rank_test_score', 'mean_fit_time', 'mean_score_time', 'mean_train_score']]
# Out:
#         params  mean_test_score  std_test_score  rank_test_score  \
# 0  {'C': 0.01}         0.983678        0.009423                6
# 1   {'C': 0.1}         0.984291        0.008619                1
# 2     {'C': 1}         0.983977        0.008796                5
# 3    {'C': 10}         0.984034        0.008848                2
# 4   {'C': 100}         0.983991        0.008879                3
# 5  {'C': 1000}         0.983987        0.008882                4
#
#    mean_fit_time  mean_score_time  mean_train_score
# 0       0.170574         0.017256          0.986962
# 1       0.176998         0.016067          0.986849
# 2       0.158372         0.012412          0.986610
# 3       0.186886         0.012736          0.986568
# 4       0.184117         0.014161          0.986554
# 5       0.179354         0.011865          0.986552

# %%
# plot of C versus train and validation scores

plt.figure(figsize=(8, 6))
plt.plot(cv_results['param_C'], cv_results['mean_test_score'])
plt.plot(cv_results['param_C'], cv_results['mean_train_score'])
plt.xlabel('C')
plt.ylabel('roc_auc')
plt.legend(['test result', 'train result'], loc='upper right')
plt.xscale('log')

# %%
# best score
best_score = model_cv.best_score_
best_score
# Out:
# 0.9842914788272321

# %%
# best params
best_params = model_cv.best_params_['C']
best_params
# Out:
# 0.1

# %%
print(f"Best Score: {best_score}")
print(f"Best Params: {best_params}")
# Out:
# Best Score: 0.9842914788272321
# Best Params: 0.1

# %% [markdown]
# **Logistic regression with optimal C**

# %%
# Instantiate the model with best C
logistic_imb = LogisticRegression(C=0.1)

# %%
# Fit the model on the train set
logistic_imb_model = logistic_imb.fit(X_train, y_train)

# %% [markdown]
# **Prediction on the train set**

# %%
# Predictions on the train set
y_train_pred = logistic_imb_model.predict(X_train)

# %%
# Confusion matrix
confusion_matrix = metrics.confusion_matrix(y_train, y_train_pred)
confusion_matrix
# Out:
# array([[198994,     26],
#        [   114,    230]])

# %%
TN = confusion_matrix[0,0] # True negative
FP = confusion_matrix[0,1] # False positive
FN = confusion_matrix[1,0] # False negative
TP = confusion_matrix[1,1] # True positive

# %%
# Accuracy
print("Accuracy:", metrics.accuracy_score(y_train, y_train_pred))

# Sensitivity
print("Sensitivity:", TP / float(TP+FN))

# Specificity
print("Specificity:", TN / float(TN+FP))

# F1 score
print("F1-score:", f1_score(y_train, y_train_pred))
# Out:
# Accuracy: 0.999297766898738
# Sensitivity: 0.6686046511627907
# Specificity: 0.9998693598633304
# F1-score: 0.7666666666666667

# %%
# classification_report
print(classification_report(y_train, y_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    199020
#            1       1.00      1.00      1.00       344
#
#     accuracy                           1.00    199364
#    macro avg       1.00      1.00      1.00    199364
# weighted avg       1.00      1.00      1.00    199364

# %% [markdown]
# **ROC on the train set**

# %%
# ROC Curve function

def draw_roc( actual, probs ):
    fpr, tpr, thresholds = metrics.roc_curve( actual, probs,
                                              drop_intermediate = False )
    auc_score = metrics.roc_auc_score( actual, probs )
    plt.figure(figsize=(5, 5))
    plt.plot( fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score )
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

    return None

# %%
# Predicted probability
y_train_pred_proba = logistic_imb_model.predict_proba(X_train)[:,1]
y_train_pred_proba
# Out:
# array([5.93239848e-05, 2.55171540e-04, 4.64545549e-04, ...,
#        3.55588656e-04, 3.60954740e-04, 1.53374857e-04])

# %%
# Plot the ROC curve
draw_roc(y_train, y_train_pred_proba)

# %% [markdown]
# We acheived very good ROC 0.99 on the train set.

# %% [markdown]
# **Lets do Prediction on the test set**

# %%
# Prediction on the test set
y_test_pred = logistic_imb_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[85279    16]
#  [   53    95]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(y_test, y_test_pred))
# Out:
# Accuracy:- 0.9991924440855307
# Sensitivity:- 0.6418918918918919
# Specificity:- 0.9998124157336303
# F1-Score:- 0.7335907335907336

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.86      0.64      0.73       148
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.82      0.87     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# **ROC on the test set**

# %%
# Predicted probability
y_test_pred_proba = logistic_imb_model.predict_proba(X_test)[:,1]

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# We can see that we have very **good ROC** on the **test set** i.e. **0.97**

# %% [markdown]
# **Model summary** (***Logistic Regression***)
#
# - **Train set**
#   - Accuracy = 0.99
#   - Sensitivity = 0.66
#   - Specificity = 0.99
#   - F1-Score = 0.76
#   - ROC = 0.99
#
# - **Test set**
#   - Accuracy = 0.99
#   - Sensitivity = 0.64
#   - Specificity = 0.99
#   - F1-Score = 0.73
#   - ROC = 0.97

# %% [markdown]
# **Overall, the model is performing well in the test set**

# %% [markdown]
# # **XGBoost**

# %%
# Importing XGBoost
from xgboost import XGBClassifier

# %% [markdown]
# **Hyperparameter Tuning**

# %%
# hyperparameter tuning with XGBoost

# creating a KFold object 
folds = 3

# specify range of hyperparameters
param_grid = {'learning_rate': [0.2, 0.6],
               'subsample': [0.3, 0.6, 0.9]}

# specify model
xgb_model = XGBClassifier(max_depth=2, n_estimators=200)

# set up GridSearchCV()
model_cv = GridSearchCV(estimator = xgb_model, 
                        param_grid = param_grid, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True)

# fit the model
model_cv.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=2,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=200,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              param_grid={'learning_rate': [0.2, 0.6],
#                          'subsample': [0.3, 0.6, 0.9]},
#              return_train_score=True, scoring='roc_auc', verbose=1)

# %%
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.442591      0.019481         0.020071        0.000737
# 1       0.403399      0.014317         0.019441        0.000360
# 2       0.343275      0.023846         0.028487        0.024207
# 3       0.310011      0.017319         0.010065        0.001100
# 4       0.321979      0.007357         0.009781        0.000917
# 5       0.308188      0.006461         0.011846        0.000612
#
#   param_learning_rate param_subsample  \
# 0                 0.2             0.3
# 1                 0.2             0.6
# 2                 0.2             0.9
# 3                 0.6             0.3
# 4                 0.6             0.6
# 5                 0.6             0.9
#
#                                      params  split0_test_score  \
# 0  {'learning_rate': 0.2, 'subsample': 0.3}           0.975099
# 1  {'learning_rate': 0.2, 'subsample': 0.6}           0.973589
# 2  {'learning_rate': 0.2, 'subsample': 0.9}           0.489041
# 3  {'learning_rate': 0.6, 'subsample': 0.3}           0.467568
# 4  {'learning_rate': 0.6, 'subsample': 0.6}           0.500000
# 5  {'learning_rate': 0.6, 'subsample': 0.9}           0.492599
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           0.983428           0.987316         0.981948        0.005096
# 1           0.982237           0.972578         0.976134        0.004335
# 2           0.506738           0.476568         0.490782        0.012379
# 3           0.500000           0.500000         0.489189        0.015289
# 4           0.500000           0.500000         0.500000        0.000000
# 5           0.472413           0.499322         0.488111        0.011435
#
#    rank_test_score  split0_train_score  split1_train_score  \
# 0                1            0.999845            0.999883
# 1                2            0.999977            0.999979
# 2                4            0.491653            0.500529
# 3                5            0.465773            0.500000
# 4                3            0.500000            0.500000
# 5                6            0.499311            0.466990
#
#    split2_train_score  mean_train_score  std_train_score
# 0            0.999851          0.999859         0.000017
# 1            0.999929          0.999962         0.000023
# 2            0.480823          0.491001         0.008058
# 3            0.500000          0.488591         0.016135
# 4            0.500000          0.500000         0.000000
# 5            0.503673          0.489991         0.016362

# %%
# # plotting
plt.figure(figsize=(16,6))

param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]} 


for n, subsample in enumerate(param_grid['subsample']):
    

    # subplot 1/n
    plt.subplot(1,len(param_grid['subsample']), n+1)
    df = cv_results[cv_results['param_subsample']==subsample]

    plt.plot(df["param_learning_rate"], df["mean_test_score"])
    plt.plot(df["param_learning_rate"], df["mean_train_score"])
    plt.xlabel('learning_rate')
    plt.ylabel('AUC')
    plt.title("subsample={0}".format(subsample))
    plt.ylim([0.60, 1])
    plt.legend(['test score', 'train score'], loc='best')
    plt.xscale('log')

# %%
model_cv.best_params_
# Out:
# {'learning_rate': 0.2, 'subsample': 0.3}

# %%
# chosen hyperparameters
# 'objective':'binary:logistic' which outputs probability rather than label, which we need for calculating auc
params = {'learning_rate': 0.2,
          'max_depth': 2, 
          'n_estimators':200,
          'subsample':0.3,
         'objective':'binary:logistic'}

# fit model on training data
xgb_imb_model = XGBClassifier(params = params)
xgb_imb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# **Prediction on the train set**

# %%
# prediction on train set
y_train_pred = xgb_imb_model.predict(X_train)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train, y_train_pred)
print(confusion)
# Out:
# [[199020      0]
#  [     3    341]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train, y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(y_train, y_train_pred))
# Out:
# Accuracy:- 0.9999849521478301
# Sensitivity:- 0.9912790697674418
# Specificity:- 1.0
# F1-Score:- 0.9956204379562044

# %%
# classification_report
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    199020
#            1       1.00      0.99      1.00       344
#
#     accuracy                           1.00    199364
#    macro avg       1.00      1.00      1.00    199364
# weighted avg       1.00      1.00      1.00    199364

# %%
# Predicted probability
y_train_pred_proba_imb_xgb = xgb_imb_model.predict_proba(X_train)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train, y_train_pred_proba_imb_xgb)
auc
# Out:
# 0.9971186721914123

# %%
# Plot the ROC curve
draw_roc(y_train, y_train_pred_proba_imb_xgb)

# %% [markdown]
# **Prediction on the test set**

# %%
# Predictions on the test set
y_test_pred = xgb_imb_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[85287     8]
#  [   40   108]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(y_test, y_test_pred))
# Out:
# Accuracy:- 0.9994382219725431
# Sensitivity:- 0.7297297297297297
# Specificity:- 0.9999062078668152
# F1-Score:- 0.8181818181818182

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.93      0.73      0.82       148
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.86      0.91     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
# Predicted probability
y_test_pred_proba = xgb_imb_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9333497971269822

# %% [markdown]
# **ROC of Test set**

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# **Model summary (xGBoost)**
#
# - **Train set**
#
#   - Accuracy = 0.99
#   - Sensitivity = 0.99
#   - Specificity = 1
#   - F1-Score = 0.99
#   - ROC_AUC = 0.99
#
# - **Test set**
#
#   - Accuracy = 0.99
#   - Sensitivity = 0.72
#   - Specificity = 0.99
#   - F1-Score = 0.81
#   - ROC_AUC = 0.93

# %% [markdown]
# Model is seemingly well performing on test set as well.

# %% [markdown]
# # **Decision Tree**

# %%
# Importing decision tree classifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Create the parameter grid 
param_grid = {
    'max_depth': range(5, 15, 5),
    'min_samples_leaf': range(50, 150, 50),
    'min_samples_split': range(50, 150, 50),
}

# Instantiate the grid search model
dtree = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator = dtree, 
                           param_grid = param_grid, 
                           scoring= 'roc_auc',
                           cv = 3, 
                           verbose = 1)

# Fit the grid search to the data
grid_search.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': range(5, 15, 5),
#                          'min_samples_leaf': range(50, 150, 50),
#                          'min_samples_split': range(50, 150, 50)},
#              scoring='roc_auc', verbose=1)

# %%
# cv results
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       1.883677      0.015808         0.008785        0.000301
# 1       1.865414      0.030952         0.009687        0.000190
# 2       1.873742      0.014510         0.008751        0.000543
# 3       1.872579      0.012082         0.009011        0.000651
# 4       3.618278      0.142516         0.011187        0.001412
# 5       3.602295      0.145332         0.010011        0.000574
# 6       3.712703      0.235197         0.014889        0.007361
# 7       3.604248      0.139446         0.010415        0.000522
#
#   param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0               5                     50                      50
# 1               5                     50                     100
# 2               5                    100                      50
# 3               5                    100                     100
# 4              10                     50                      50
# 5              10                     50                     100
# 6              10                    100                      50
# 7              10                    100                     100
#
#                                               params  split0_test_score  \
# 0  {'max_depth': 5, 'min_samples_leaf': 50, 'min_...           0.930095
# 1  {'max_depth': 5, 'min_samples_leaf': 50, 'min_...           0.930095
# 2  {'max_depth': 5, 'min_samples_leaf': 100, 'min...           0.938053
# 3  {'max_depth': 5, 'min_samples_leaf': 100, 'min...           0.938053
# 4  {'max_depth': 10, 'min_samples_leaf': 50, 'min...           0.961034
# 5  {'max_depth': 10, 'min_samples_leaf': 50, 'min...           0.961027
# 6  {'max_depth': 10, 'min_samples_leaf': 100, 'mi...           0.943187
# 7  {'max_depth': 10, 'min_samples_leaf': 100, 'mi...           0.926023
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           0.945270           0.927363         0.934243        0.007877
# 1           0.945270           0.936126         0.937163        0.006239
# 2           0.936641           0.935985         0.936893        0.000863
# 3           0.936641           0.935985         0.936893        0.000863
# 4           0.968009           0.914781         0.947941        0.023620
# 5           0.968034           0.889113         0.939391        0.035667
# 6           0.963205           0.906133         0.937508        0.023643
# 7           0.962113           0.906117         0.931418        0.023176
#
#    rank_test_score
# 0                7
# 1                4
# 2                5
# 3                5
# 4                1
# 5                2
# 6                3
# 7                8

# %%
grid_search.best_score_
# Out:
# 0.9479412628745844

# %%
print(grid_search.best_estimator_)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=50, min_samples_split=50)

# %%
# Model with optimal hyperparameters
dt_imb_model = DecisionTreeClassifier(criterion = "gini", 
                                  random_state = 100,
                                  max_depth=10, 
                                  min_samples_leaf=50,
                                  min_samples_split=50)

dt_imb_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=50, min_samples_split=50,
#                        random_state=100)

# %% [markdown]
# **Prediction on the train set**

# %%
# Predictions on the train set
y_train_pred = dt_imb_model.predict(X_train)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train, y_train_pred)
print(confusion)
# Out:
# [[198982     38]
#  [   118    226]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train, y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(y_train, y_train_pred))
# Out:
# Accuracy:- 0.9992175116871652
# Sensitivity:- 0.6569767441860465
# Specificity:- 0.9998090644156367
# F1-Score:- 0.743421052631579

# %%
# classification_report
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    199020
#            1       0.86      0.66      0.74       344
#
#     accuracy                           1.00    199364
#    macro avg       0.93      0.83      0.87    199364
# weighted avg       1.00      1.00      1.00    199364

# %%
# Predicted probability
y_train_pred_proba = dt_imb_model.predict_proba(X_train)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train, y_train_pred_proba)
auc
# Out:
# 0.9642430686526772

# %%
# Plot the ROC curve
draw_roc(y_train, y_train_pred_proba)

# %% [markdown]
# Prediction on the test set

# %%
# Predictions on the test set
y_test_pred = dt_imb_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[85272    23]
#  [   58    90]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(y_train, y_train_pred))
# Out:
# Accuracy:- 0.9990519995786665
# Sensitivity:- 0.6081081081081081
# Specificity:- 0.9997303476170936
# F1-Score:- 0.743421052631579

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.80      0.61      0.69       148
#
#     accuracy                           1.00     85443
#    macro avg       0.90      0.80      0.84     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
# Predicted probability
y_test_pred_proba = dt_imb_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9205109690850355

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# **Model summary**(***Decision Tree***)
#
# - **Train set**
#   - Accuracy = 0.99
#   - Sensitivity = 0.65
#   - Specificity = 0.99
#   - F1-Score = 0.74
#   - ROC-AUC = 0.96
#
# - **Test set**
#   - Accuracy = 0.99
#   - Sensitivity = 0.60
#   - Specificity = 0.99
#   - F1 Score = 0.74
#   - ROC-AUC = 0.92

# %% [markdown]
# **Random forest**

# %%
# Importing random forest classifier
from sklearn.ensemble import RandomForestClassifier

# %%
param_grid = {
    'max_depth': range(5,10,5) ,
    'min_samples_leaf': [50, 100],
    'min_samples_split': [50, 100],
    'n_estimators': [100,200], 
    'max_features': [10, 20]
}
# Create a based model
rf = RandomForestClassifier()

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, 
                           param_grid = param_grid, 
                           cv = 2,
                           n_jobs = -1,
                           verbose = 1, 
                           return_train_score=True)

# Fit the model
grid_search.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 16 candidates, totalling 32 fits
# GridSearchCV(cv=2, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': range(5, 10, 5), 'max_features': [10, 20],
#                          'min_samples_leaf': [50, 100],
#                          'min_samples_split': [50, 100],
#                          'n_estimators': [100, 200]},
#              return_train_score=True, verbose=1)

# %%
# cv results
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       45.186126      0.145962         0.171952        0.029057
# 1       88.594728      0.304867         0.256368        0.006840
# 2       44.970823      0.112233         0.134532        0.016681
# 3       89.258657      0.151083         0.327710        0.009860
# 4       45.093458      0.426541         0.157340        0.000365
# 5       87.618042      0.550143         0.224513        0.007828
# 6       43.548604      0.174450         0.133507        0.001763
# 7       87.158921      1.071596         0.242759        0.007372
# 8       87.084090      0.795117         0.141713        0.021097
# 9      171.244057      0.467687         0.262078        0.050038
# 10      87.719228      0.091151         0.115985        0.005884
# 11     171.787486      0.078878         0.230223        0.011253
# 12      86.059655      0.256647         0.168215        0.011106
# 13     157.962674      0.321433         0.184116        0.002968
# 14      84.830855      0.097828         0.125499        0.023211
# 15     137.865759      7.832595         0.177237        0.011062
#
#    param_max_depth param_max_features param_min_samples_leaf  \
# 0                5                 10                     50
# 1                5                 10                     50
# 2                5                 10                     50
# 3                5                 10                     50
# 4                5                 10                    100
# 5                5                 10                    100
# 6                5                 10                    100
# 7                5                 10                    100
# 8                5                 20                     50
# 9                5                 20                     50
# 10               5                 20                     50
# 11               5                 20                     50
# 12               5                 20                    100
# 13               5                 20                    100
# 14               5                 20                    100
# 15               5                 20                    100
#
#    param_min_samples_split param_n_estimators  \
# 0                       50                100
# 1                       50                200
# 2                      100                100
# 3                      100                200
# 4                       50                100
# 5                       50                200
# 6                      100                100
# 7                      100                200
# 8                       50                100
# 9                       50                200
# 10                     100                100
# 11                     100                200
# 12                      50                100
# 13                      50                200
# 14                     100                100
# 15                     100                200
#
#                                                params  split0_test_score  \
# 0   {'max_depth': 5, 'max_features': 10, 'min_samp...           0.999228
# 1   {'max_depth': 5, 'max_features': 10, 'min_samp...           0.999248
# 2   {'max_depth': 5, 'max_features': 10, 'min_samp...           0.999218
# 3   {'max_depth': 5, 'max_features': 10, 'min_samp...           0.999228
# 4   {'max_depth': 5, 'max_features': 10, 'min_samp...           0.999137
# 5   {'max_depth': 5, 'max_features': 10, 'min_samp...           0.999127
# 6   {'max_depth': 5, 'max_features': 10, 'min_samp...           0.999097
# 7   {'max_depth': 5, 'max_features': 10, 'min_samp...           0.999117
# 8   {'max_depth': 5, 'max_features': 20, 'min_samp...           0.999157
# 9   {'max_depth': 5, 'max_features': 20, 'min_samp...           0.999157
# 10  {'max_depth': 5, 'max_features': 20, 'min_samp...           0.999157
# 11  {'max_depth': 5, 'max_features': 20, 'min_samp...           0.999157
# 12  {'max_depth': 5, 'max_features': 20, 'min_samp...           0.999147
# 13  {'max_depth': 5, 'max_features': 20, 'min_samp...           0.999147
# 14  {'max_depth': 5, 'max_features': 20, 'min_samp...           0.999147
# 15  {'max_depth': 5, 'max_features': 20, 'min_samp...           0.999147
#
#     split1_test_score  mean_test_score  std_test_score  rank_test_score  \
# 0            0.999207         0.999218        0.000010                1
# 1            0.999187         0.999218        0.000030                1
# 2            0.999167         0.999192        0.000025                4
# 3            0.999177         0.999202        0.000025                3
# 4            0.999037         0.999087        0.000050               16
# 5            0.999117         0.999122        0.000005               13
# 6            0.999137         0.999117        0.000020               14
# 7            0.999077         0.999097        0.000020               15
# 8            0.999107         0.999132        0.000025                7
# 9            0.999117         0.999137        0.000020                5
# 10           0.999117         0.999137        0.000020                5
# 11           0.999107         0.999132        0.000025                7
# 12           0.999117         0.999132        0.000015                7
# 13           0.999117         0.999132        0.000015                7
# 14           0.999117         0.999132        0.000015                7
# 15           0.999117         0.999132        0.000015                7
#
#     split0_train_score  split1_train_score  mean_train_score  std_train_score
# 0             0.999238            0.999258          0.999248         0.000010
# 1             0.999258            0.999248          0.999253         0.000005
# 2             0.999228            0.999218          0.999223         0.000005
# 3             0.999278            0.999248          0.999263         0.000015
# 4             0.999097            0.999057          0.999077         0.000020
# 5             0.999117            0.999127          0.999122         0.000005
# 6             0.999087            0.999187          0.999137         0.000050
# 7             0.999087            0.999117          0.999102         0.000015
# 8             0.999207            0.999187          0.999197         0.000010
# 9             0.999218            0.999187          0.999202         0.000015
# 10            0.999207            0.999187          0.999197         0.000010
# 11            0.999207            0.999187          0.999197         0.000010
# 12            0.999157            0.999197          0.999177         0.000020
# 13            0.999147            0.999197          0.999172         0.000025
# 14            0.999147            0.999197          0.999172         0.000025
# 15            0.999157            0.999197          0.999177         0.000020

# %%
grid_search.best_score_
# Out:
# 0.9992175116871651

# %%
grid_search.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 10,
#  'min_samples_leaf': 50,
#  'min_samples_split': 50,
#  'n_estimators': 100}

# %%
# model with the best hyperparameters

rfc_imb_model = RandomForestClassifier(bootstrap=True,
                                        max_depth = 5,
                                        max_features = 10,
                                        min_samples_leaf = 50,
                                        min_samples_split = 50,
                                        n_estimators = 100)

# %%
# Fit the model
rfc_imb_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, max_features=10, min_samples_leaf=50,
#                        min_samples_split=50)

# %% [markdown]
# **Prediction on the train set**

# %%
# predictions on train test
y_train_pred = rfc_imb_model.predict(X_train)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train, y_train_pred)
print(confusion)
# Out:
# [[198984     36]
#  [    88    256]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train, y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(y_train, y_train_pred))
# Out:
# Accuracy:- 0.9993780221103108
# Sensitivity:- 0.7441860465116279
# Specificity:- 0.9998191136569189
# F1-Score:- 0.8050314465408805

# %%
# classification_report
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    199020
#            1       0.88      0.74      0.81       344
#
#     accuracy                           1.00    199364
#    macro avg       0.94      0.87      0.90    199364
# weighted avg       1.00      1.00      1.00    199364

# %%
# Predicted probability
y_train_pred_proba = rfc_imb_model.predict_proba(X_train)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train, y_train_pred_proba)
auc
# Out:
# 0.9798298362557929

# %%
# Plot the ROC curve
draw_roc(y_train, y_train_pred_proba)

# %% [markdown]
# **Prediction on the test set**

# %%
# Predictions on the test set
y_test_pred = rfc_imb_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[85274    21]
#  [   48   100]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(y_train, y_train_pred))
# Out:
# Accuracy:- 0.9991924440855307
# Sensitivity:- 0.6756756756756757
# Specificity:- 0.9997537956503898
# F1-Score:- 0.8050314465408805

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.83      0.68      0.74       148
#
#     accuracy                           1.00     85443
#    macro avg       0.91      0.84      0.87     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
# Predicted probability
y_test_pred_proba = rfc_imb_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9608903440048291

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# **Model summary** (***Random Forest***)
#
# - **Train set**
#   - Accuracy = 0.99
#   - Sensitivity = 0.74
#   - Specificity = 0.99
#   - F1-Score = 0.80
#   - ROC-AUC = 0.98
# - **Test set**
#   - Accuracy = 0.99
#   - Sensitivity = 0.68
#   - Specificity = 0.99
#   - F1 Score = 0.80
#   - ROC-AUC = 0.95

# %% [markdown]
# # **Choosing best model on the imbalanced data**

# %% [markdown]
# - We can see that among all the models we tried (**Logistic Regression**, **XGBoost**, **Decision Tree**, and **Random Forest**), almost all of them have performed well.
#
# - More specifically, **Logistic Regression** and **XGBoost** performed best in terms of **ROC-AUC score**.
#
# - But if we were to choose one of them, we can go for the best — **XGBoost**, which gives us:
#   - **ROC score of 0.99** on the **train data**
#   - **ROC score of 0.97** on the **test data**

# %% [markdown]
# **Print the FPR,TPR & select the best threshold from the roc curve for the best model**

# %%
print('Train auc =', metrics.roc_auc_score(y_train, y_train_pred_proba_imb_xgb))
fpr, tpr, thresholds = metrics.roc_curve(y_train, y_train_pred_proba_imb_xgb)

threshold = thresholds[np.argmax(tpr-fpr)]
print("Threshold=",threshold)
# Out:
# Train auc = 0.9971186721914123
# Threshold= 0.083586976

# %% [markdown]
# We can see that the **threshold** is **0.083**, for which the TPR is the highest and FPR is the lowest and we got the best ROC score.

# %% [markdown]
# # **Handling Class Imbalance**
#
# As we can see, the data is heavily imbalanced.
# We will try several approaches to address this issue.

# %% [markdown]
# **Resampling Techniques**
#
# - **Undersampling**
#   Randomly reduce the majority class instances to match the minority class size.
#
# - **Oversampling**
#   Duplicate or generate synthetic instances of the minority class to match the majority class size.
#
# - **SMOTE (Synthetic Minority Over-sampling Technique)**
#   Create synthetic minority class instances by interpolating between neighboring instances.
#
# - **ADASYN (Adaptive Synthetic Sampling)**
#   Generate synthetic instances in regions where the minority class is difficult to learn.

# %% [markdown]
# **Why Undersampling is not Preferred in Industry**
#
# - **Loss of information**: Undersampling reduces the size of the majority class, potentially discarding important patterns and leading to decreased performance on that class.
#
# - **Incomplete understanding of the problem**: By removing data points from the majority class, we risk losing valuable insights that may contribute to the overall predictive power of the model.
#
# - **Risk with small datasets**: If the dataset is already small, undersampling further reduces the dataset size, which can increase the chance of **overfitting** and result in poor generalization performance.

# %% [markdown]
# **SMOTE** **(Synthetic Minority Oversampling Technique)**

# %%
# Importing SMOTE
from imblearn.over_sampling import SMOTE

# %%
# instantiate SMOTE
sm = SMOTE(random_state=27)

# fitting the SMOTE to the train set
X_train_smote, y_train_smote = sm.fit_resample(X_train, y_train)

# %%
print('Before SMOTE oversampling X_train shape=',X_train.shape)
print('After SMOTE oversampling X_train shape=',X_train_smote.shape)
# Out:
# Before SMOTE oversampling X_train shape= (199364, 29)
# After SMOTE oversampling X_train shape= (398040, 29)

# %% [markdown]
# **We will start with Model building after balancing data with SMOTE**

# %% [markdown]
# # **Logistic Regression** (by SMOTE)

# %%
# Creating KFold object with 5 splits
folds = KFold(n_splits=5, shuffle=True, random_state=4)

# Specify params
params = {"C": [0.01, 0.1, 1, 10, 100, 1000]}

# Specifing score as roc-auc
model_cv = GridSearchCV(estimator = LogisticRegression(),
                        param_grid = params, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True) 

# Fit the model
model_cv.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=4, shuffle=True),
#              estimator=LogisticRegression(),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100, 1000]},
#              return_train_score=True, scoring='roc_auc', verbose=1)

# %%
# results of grid search CV
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.500065      0.033137         0.030227        0.010561    0.01
# 1       0.517458      0.025438         0.019948        0.002464     0.1
# 2       0.515828      0.023734         0.024317        0.006151       1
# 3       0.483950      0.029683         0.021243        0.003676      10
# 4       0.497258      0.019975         0.023263        0.004522     100
# 5       0.500355      0.020875         0.019155        0.003359    1000
#
#         params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'C': 0.01}           0.992174           0.992258           0.991851
# 1   {'C': 0.1}           0.992291           0.992367           0.991974
# 2     {'C': 1}           0.992306           0.992383           0.991992
# 3    {'C': 10}           0.992308           0.992386           0.991993
# 4   {'C': 100}           0.992308           0.992386           0.991993
# 5  {'C': 1000}           0.992308           0.992386           0.991993
#
#    split3_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# 0           0.992443  ...         0.992204        0.000197                6
# 1           0.992565  ...         0.992321        0.000195                5
# 2           0.992575  ...         0.992333        0.000192                4
# 3           0.992577  ...         0.992336        0.000192                3
# 4           0.992577  ...         0.992336        0.000192                1
# 5           0.992577  ...         0.992336        0.000192                2
#
#    split0_train_score  split1_train_score  split2_train_score  \
# 0            0.992238            0.992209            0.992291
# 1            0.992351            0.992320            0.992408
# 2            0.992364            0.992336            0.992423
# 3            0.992367            0.992338            0.992425
# 4            0.992367            0.992338            0.992425
# 5            0.992367            0.992338            0.992425
#
#    split3_train_score  split4_train_score  mean_train_score  std_train_score
# 0            0.992116            0.992200          0.992211         0.000057
# 1            0.992241            0.992322          0.992328         0.000054
# 2            0.992251            0.992326          0.992340         0.000056
# 3            0.992253            0.992336          0.992343         0.000056
# 4            0.992253            0.992336          0.992344         0.000056
# 5            0.992253            0.992336          0.992344         0.000056
#
# [6 rows x 21 columns]

# %%
# plot of C versus train and validation scores

plt.figure(figsize=(8, 6))
plt.plot(cv_results['param_C'], cv_results['mean_test_score'])
plt.plot(cv_results['param_C'], cv_results['mean_train_score'])
plt.xlabel('C')
plt.ylabel('roc_auc')
plt.legend(['test result', 'train result'], loc='best')
plt.xscale('log')

# %%
print(model_cv.best_score_)
print(model_cv.best_params_['C'])
# Out:
# 0.9923363912621573
# 100

# %%
# Instantiate the model with best C
logistic_bal_smote = LogisticRegression(C=100)

# %%
# Fit the model on the train set
logistic_bal_smote_model = logistic_bal_smote.fit(X_train_smote, y_train_smote)

# %% [markdown]
# **Prediction on the train set**

# %%
# Predictions on the train set
y_train_pred = logistic_bal_smote_model.predict(X_train_smote)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_smote, y_train_pred)
print(confusion)
# Out:
# [[194235   4785]
#  [ 12073 186947]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_smote, y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.9576474726158175
# Sensitivity:- 0.9393377549994976
# Specificity:- 0.9759571902321375

# %%
# classification_report
print(classification_report(y_train_smote, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96    199020
#            1       0.98      0.94      0.96    199020
#
#     accuracy                           0.96    398040
#    macro avg       0.96      0.96      0.96    398040
# weighted avg       0.96      0.96      0.96    398040

# %%
# Predicted probability
y_train_pred_proba_log_bal_smote = logistic_bal_smote_model.predict_proba(X_train_smote)[:,1]

# %%
# Plot the ROC curve
draw_roc(y_train_smote, y_train_pred_proba_log_bal_smote)

# %% [markdown]
# **Prediction on the test set**

# %%
# Prediction on the test set
y_test_pred = logistic_bal_smote_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[83171  2124]
#  [   18   130]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.9749306555247358
# Sensitivity:- 0.8783783783783784
# Specificity:- 0.9750981886394279

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     85295
#            1       0.06      0.88      0.11       148
#
#     accuracy                           0.97     85443
#    macro avg       0.53      0.93      0.55     85443
# weighted avg       1.00      0.97      0.99     85443

# %% [markdown]
# **ROC on the test set**

# %%
# Predicted probability
y_test_pred_proba = logistic_bal_smote_model.predict_proba(X_test)[:,1]

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# **Model summary** **(Logistic with SMOTE)**
#
# **Train set**
# - Accuracy = 0.95
# - Sensitivity = 0.94
# - Specificity = 0.97
# - ROC = 0.99
#
# **Test set**
# - Accuracy = 0.97
# - Sensitivity = 0.88
# - Specificity = 0.97
# - ROC = 0.97

# %% [markdown]
# # **XGBoost**(by SMOTE)

# %%
# hyperparameter tuning with XGBoost

# creating a KFold object 
folds = 3

# specify range of hyperparameters
param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]}          


# specify model
xgb_model = XGBClassifier(max_depth=2, n_estimators=200)

# set up GridSearchCV()
model_cv = GridSearchCV(estimator = xgb_model, 
                        param_grid = param_grid, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True)      

# fit the model
model_cv.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=2,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=200,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              param_grid={'learning_rate': [0.2, 0.6],
#                          'subsample': [0.3, 0.6, 0.9]},
#              return_train_score=True, scoring='roc_auc', verbose=1)

# %%
# cv results
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.697708      0.016439         0.035792        0.000388
# 1       0.702741      0.017220         0.035476        0.001208
# 2       0.669385      0.008615         0.036801        0.002484
# 3       0.675247      0.004093         0.034377        0.000250
# 4       0.672119      0.002170         0.035226        0.000720
# 5       0.700720      0.036588         0.036389        0.001856
#
#   param_learning_rate param_subsample  \
# 0                 0.2             0.3
# 1                 0.2             0.6
# 2                 0.2             0.9
# 3                 0.6             0.3
# 4                 0.6             0.6
# 5                 0.6             0.9
#
#                                      params  split0_test_score  \
# 0  {'learning_rate': 0.2, 'subsample': 0.3}           0.999768
# 1  {'learning_rate': 0.2, 'subsample': 0.6}           0.999756
# 2  {'learning_rate': 0.2, 'subsample': 0.9}           0.999729
# 3  {'learning_rate': 0.6, 'subsample': 0.3}           0.999971
# 4  {'learning_rate': 0.6, 'subsample': 0.6}           0.999968
# 5  {'learning_rate': 0.6, 'subsample': 0.9}           0.999961
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           0.999742           0.999755         0.999755        0.000011
# 1           0.999724           0.999749         0.999743        0.000014
# 2           0.999703           0.999742         0.999724        0.000016
# 3           0.999936           0.999959         0.999955        0.000015
# 4           0.999933           0.999964         0.999955        0.000016
# 5           0.999945           0.999958         0.999955        0.000007
#
#    rank_test_score  split0_train_score  split1_train_score  \
# 0                4            0.999776            0.999794
# 1                5            0.999770            0.999775
# 2                6            0.999744            0.999775
# 3                1            0.999983            0.999985
# 4                2            0.999982            0.999990
# 5                3            0.999983            0.999984
#
#    split2_train_score  mean_train_score  std_train_score
# 0            0.999785          0.999785         0.000008
# 1            0.999769          0.999771         0.000003
# 2            0.999764          0.999761         0.000013
# 3            0.999979          0.999982         0.000003
# 4            0.999983          0.999985         0.000004
# 5            0.999988          0.999985         0.000002

# %%
# # plotting
plt.figure(figsize=(16,6))

param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]} 


for n, subsample in enumerate(param_grid['subsample']):
    

    # subplot 1/n
    plt.subplot(1,len(param_grid['subsample']), n+1)
    df = cv_results[cv_results['param_subsample']==subsample]

    plt.plot(df["param_learning_rate"], df["mean_test_score"])
    plt.plot(df["param_learning_rate"], df["mean_train_score"])
    plt.xlabel('learning_rate')
    plt.ylabel('AUC')
    plt.title("subsample={0}".format(subsample))
    plt.ylim([0.60, 1])
    plt.legend(['test score', 'train score'], loc='best')
    plt.xscale('log')

# %% [markdown]
# We see that the train score almost touches to 1

# %%
model_cv.best_params_
# Out:
# {'learning_rate': 0.6, 'subsample': 0.3}

# %%
# chosen hyperparameters
# 'objective':'binary:logistic' outputs probability rather than label, which we need for calculating auc
params = {'learning_rate': 0.6,
          'max_depth': 2, 
          'n_estimators':200,
          'subsample':0.3,
         'objective':'binary:logistic'}

# fit model on training data
xgb_bal_smote_model = XGBClassifier(params = params)
xgb_bal_smote_model.fit(X_train_smote, y_train_smote)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# **Prediction on the train set**

# %%
# Predictions on the train set
y_train_pred = xgb_bal_smote_model.predict(X_train_smote)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_smote, y_train_pred)
print(confusion)
# Out:
# [[199020      0]
#  [     0 199020]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_smote, y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 1.0
# Sensitivity:- 1.0
# Specificity:- 1.0

# %%
# classification_report
print(classification_report(y_train_smote, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    199020
#            1       1.00      1.00      1.00    199020
#
#     accuracy                           1.00    398040
#    macro avg       1.00      1.00      1.00    398040
# weighted avg       1.00      1.00      1.00    398040

# %%
# Predicted probability
y_train_pred_proba = xgb_bal_smote_model.predict_proba(X_train_smote)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train_smote, y_train_pred_proba)
auc
# Out:
# 1.0

# %%
# Plot the ROC curve
draw_roc(y_train_smote, y_train_pred_proba)

# %% [markdown]
# **Prediction on the test set**

# %%
# Predictions on the test set
y_test_pred = xgb_bal_smote_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[85255    40]
#  [   28   120]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.999204147794436
# Sensitivity:- 0.8108108108108109
# Specificity:- 0.9995310393340758

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.75      0.81      0.78       148
#
#     accuracy                           1.00     85443
#    macro avg       0.87      0.91      0.89     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
# Predicted probability
y_test_pred_proba = xgb_bal_smote_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.97558315100375

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# **Model summary** **(xGBoost)**
#
# **Train set**
# - Accuracy = 0.99
# - Sensitivity = 1.0
# - Specificity = 0.99
# - ROC-AUC = 1.0
#
# **Test set**
# - Accuracy = 0.99
# - Sensitivity = 0.81
# - Specificity = 0.99
# - ROC-AUC = 0.98

# %% [markdown]
# # **Decision Tree** (by SMOTE)

# %%
# Create the parameter grid 
param_grid = {
    'max_depth': range(5, 15, 5),
    'min_samples_leaf': range(50, 150, 50),
    'min_samples_split': range(50, 150, 50),
}


# Instantiate the grid search model
dtree = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator = dtree, 
                           param_grid = param_grid, 
                           scoring= 'roc_auc',
                           cv = 3, 
                           verbose = 1)

# Fit the grid search to the data
grid_search.fit(X_train_smote,y_train_smote)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': range(5, 15, 5),
#                          'min_samples_leaf': range(50, 150, 50),
#                          'min_samples_split': range(50, 150, 50)},
#              scoring='roc_auc', verbose=1)

# %%
# cv results
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       3.762846      0.041275         0.021579        0.001053
# 1       3.730543      0.002441         0.021716        0.001997
# 2       3.717770      0.000534         0.020315        0.001727
# 3       3.763808      0.054577         0.021534        0.000747
# 4       6.797839      0.089438         0.020217        0.000571
# 5       6.814322      0.061316         0.023065        0.001566
# 6       6.789291      0.084130         0.021032        0.000528
# 7       6.765564      0.081808         0.021603        0.000861
#
#   param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0               5                     50                      50
# 1               5                     50                     100
# 2               5                    100                      50
# 3               5                    100                     100
# 4              10                     50                      50
# 5              10                     50                     100
# 6              10                    100                      50
# 7              10                    100                     100
#
#                                               params  split0_test_score  \
# 0  {'max_depth': 5, 'min_samples_leaf': 50, 'min_...           0.991320
# 1  {'max_depth': 5, 'min_samples_leaf': 50, 'min_...           0.991320
# 2  {'max_depth': 5, 'min_samples_leaf': 100, 'min...           0.991431
# 3  {'max_depth': 5, 'min_samples_leaf': 100, 'min...           0.991431
# 4  {'max_depth': 10, 'min_samples_leaf': 50, 'min...           0.998412
# 5  {'max_depth': 10, 'min_samples_leaf': 50, 'min...           0.998394
# 6  {'max_depth': 10, 'min_samples_leaf': 100, 'mi...           0.998409
# 7  {'max_depth': 10, 'min_samples_leaf': 100, 'mi...           0.998403
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           0.990866           0.991292         0.991160        0.000208
# 1           0.990893           0.991293         0.991169        0.000196
# 2           0.990942           0.991325         0.991233        0.000210
# 3           0.990942           0.991322         0.991232        0.000210
# 4           0.998407           0.998644         0.998488        0.000111
# 5           0.998440           0.998630         0.998488        0.000102
# 6           0.998483           0.998482         0.998458        0.000035
# 7           0.998485           0.998508         0.998465        0.000045
#
#    rank_test_score
# 0                8
# 1                7
# 2                5
# 3                6
# 4                2
# 5                1
# 6                4
# 7                3

# %%
grid_search.best_score_
# Out:
# 0.9984881040705123

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=50, min_samples_split=100)

# %%
# Model with optimal hyperparameters
dt_bal_smote_model = DecisionTreeClassifier(criterion = "gini", 
                                  random_state = 100,
                                  max_depth=10, 
                                  min_samples_leaf=50,
                                  min_samples_split=100)

dt_bal_smote_model.fit(X_train_smote, y_train_smote)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=50, min_samples_split=100,
#                        random_state=100)

# %% [markdown]
# **Prediction on the train set**

# %%
# Predictions on the train set
y_train_pred = dt_bal_smote_model.predict(X_train_smote)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_smote, y_train_pred)
print(confusion)
# Out:
# [[195552   3468]
#  [  1610 197410]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_smote, y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.9872424881921414
# Sensitivity:- 0.9919103607677621
# Specificity:- 0.9825746156165209

# %%
# classification_report
print(classification_report(y_train_smote, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99    199020
#            1       0.98      0.99      0.99    199020
#
#     accuracy                           0.99    398040
#    macro avg       0.99      0.99      0.99    398040
# weighted avg       0.99      0.99      0.99    398040

# %%
# Predicted probability
y_train_pred_proba = dt_bal_smote_model.predict_proba(X_train_smote)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train_smote, y_train_pred_proba)
auc
# Out:
# 0.9990155657304249

# %%
# Plot the ROC curve
draw_roc(y_train_smote, y_train_pred_proba)

# %% [markdown]
# **Prediction on the test set**

# %%
# Predictions on the test set
y_test_pred = dt_bal_smote_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[83761  1534]
#  [   29   119]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.9817071029809347
# Sensitivity:- 0.8040540540540541
# Specificity:- 0.982015358461809

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     85295
#            1       0.07      0.80      0.13       148
#
#     accuracy                           0.98     85443
#    macro avg       0.54      0.89      0.56     85443
# weighted avg       1.00      0.98      0.99     85443

# %%
# Predicted probability
y_test_pred_proba = dt_bal_smote_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9001736818006821

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# **Model summary** **(Decision Tree)**
#
# **Train set**
# - Accuracy = 0.98
# - Sensitivity = 0.99
# - Specificity = 0.98
# - ROC-AUC = 0.99
#
# **Test set**
# - Accuracy = 0.98
# - Sensitivity = 0.80
# - Specificity = 0.98
# - ROC-AUC = 0.90

# %% [markdown]
# ## **AdaSyn (Adaptive Synthetic Sampling)**

# %%
# importing adasyn
from imblearn.over_sampling import ADASYN

# %%
# Instantiate adasyn
ada = ADASYN(random_state=0)
X_train_adasyn, y_train_adasyn = ada.fit_resample(X_train, y_train)

# %%
from collections import Counter

# Before sampling class distribution
print('Before sampling class distribution:', Counter(y_train))

# New class distribution
print('New class distribution:', Counter(y_train_adasyn))
# Out:
# Before sampling class distribution: Counter({0: 199020, 1: 344})
# New class distribution: Counter({1: 199035, 0: 199020})

# %% [markdown]
# # **Logistic Regression** (with Adasyn)

# %%
# Creating KFold object with 3 splits
folds = KFold(n_splits=3, shuffle=True, random_state=4)

# Specify params
params = {"C": [0.01, 0.1, 1, 10, 100, 1000]}

# Specifing score as roc-auc
model_cv = GridSearchCV(estimator = LogisticRegression(),
                        param_grid = params, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True) 

# Fit the model
model_cv.fit(X_train_adasyn, y_train_adasyn)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# GridSearchCV(cv=KFold(n_splits=3, random_state=4, shuffle=True),
#              estimator=LogisticRegression(),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100, 1000]},
#              return_train_score=True, scoring='roc_auc', verbose=1)

# %%
# results of grid search CV
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.447226      0.013261         0.033299        0.002461    0.01
# 1       0.485859      0.046149         0.040661        0.008347     0.1
# 2       0.444528      0.029379         0.035441        0.004964       1
# 3       0.457490      0.028706         0.034767        0.005757      10
# 4       0.434728      0.025694         0.039570        0.003861     100
# 5       0.418613      0.022558         0.036356        0.005202    1000
#
#         params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'C': 0.01}           0.971572           0.971028           0.971375
# 1   {'C': 0.1}           0.971841           0.971292           0.971660
# 2     {'C': 1}           0.971868           0.971315           0.971685
# 3    {'C': 10}           0.971869           0.971316           0.971688
# 4   {'C': 100}           0.971869           0.971316           0.971688
# 5  {'C': 1000}           0.971869           0.971316           0.971688
#
#    mean_test_score  std_test_score  rank_test_score  split0_train_score  \
# 0         0.971325        0.000225                6            0.971366
# 1         0.971598        0.000229                5            0.971622
# 2         0.971622        0.000230                4            0.971648
# 3         0.971624        0.000230                3            0.971649
# 4         0.971625        0.000230                2            0.971649
# 5         0.971625        0.000230                1            0.971649
#
#    split1_train_score  split2_train_score  mean_train_score  std_train_score
# 0            0.971372            0.971327          0.971355         0.000020
# 1            0.971639            0.971628          0.971629         0.000007
# 2            0.971661            0.971655          0.971654         0.000005
# 3            0.971663            0.971657          0.971657         0.000006
# 4            0.971663            0.971658          0.971657         0.000006
# 5            0.971663            0.971658          0.971657         0.000006

# %%
# plot of C versus train and validation scores

plt.figure(figsize=(8, 6))
plt.plot(cv_results['param_C'], cv_results['mean_test_score'])
plt.plot(cv_results['param_C'], cv_results['mean_train_score'])
plt.xlabel('C')
plt.ylabel('roc_auc')
plt.legend(['test result', 'train result'], loc='upper left')
plt.xscale('log')

# %%
print(model_cv.best_score_)
print(model_cv.best_params_)
# Out:
# 0.9716245361721721
# {'C': 1000}

# %% [markdown]
# **Logistic regression with optimal C**

# %%
# Instantiate the model with best C
logistic_bal_adasyn = LogisticRegression(C=1000)

# %%
# Fit the model on the train set
logistic_bal_adasyn_model = logistic_bal_adasyn.fit(X_train_adasyn, y_train_adasyn)

# %% [markdown]
# **Prediction on the train set**

# %%
# Predictions on the train set
y_train_pred = logistic_bal_adasyn_model.predict(X_train_adasyn)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_adasyn, y_train_pred)
print(confusion)
# Out:
# [[183446  15574]
#  [ 20931 178104]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_adasyn, y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))

# F1 score
print("F1-Score:-", f1_score(y_train_adasyn, y_train_pred))
# Out:
# Accuracy:- 0.9082915677481755
# Sensitivity:- 0.8948375913784008
# Specificity:- 0.9217465581348608
# F1-Score:- 0.9070440754444085

# %%
# classification_report
print(classification_report(y_train_adasyn, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91    199020
#            1       0.92      0.89      0.91    199035
#
#     accuracy                           0.91    398055
#    macro avg       0.91      0.91      0.91    398055
# weighted avg       0.91      0.91      0.91    398055

# %%
 # Predicted probability
y_train_pred_proba = logistic_bal_adasyn_model.predict_proba(X_train_adasyn)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train_adasyn, y_train_pred_proba)
auc
# Out:
# 0.9716573742677831

# %%
# Plot the ROC curve
draw_roc(y_train_adasyn, y_train_pred_proba)

# %% [markdown]
# **Prediction on the test set**

# %%
# Prediction on the test set
y_test_pred = logistic_bal_adasyn_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[78521  6774]
#  [   15   133]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.9205435202415646
# Sensitivity:- 0.8986486486486487
# Specificity:- 0.9205815112257459

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96     85295
#            1       0.02      0.90      0.04       148
#
#     accuracy                           0.92     85443
#    macro avg       0.51      0.91      0.50     85443
# weighted avg       1.00      0.92      0.96     85443

# %%
# Predicted probability
y_test_pred_proba = logistic_bal_adasyn_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9688064317321601

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# **Model summary** **(Logistic Regression with Adasyn)**
#
# **Train set**
# - Accuracy = 0.91
# - Sensitivity = 0.89
# - Specificity = 0.92
# - ROC = 0.97
#
# **Test set**
# - Accuracy = 0.92
# - Sensitivity = 0.90
# - Specificity = 0.92
# - ROC = 0.97

# %% [markdown]
# # **XGBoost (with Adasyn)**

# %%
# hyperparameter tuning with XGBoost

# creating a KFold object 
folds = 3

# specify range of hyperparameters
param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]}          


# specify model
xgb_model = XGBClassifier(max_depth=2, n_estimators=200)

# set up GridSearchCV()
model_cv = GridSearchCV(estimator = xgb_model, 
                        param_grid = param_grid, 
                        scoring= 'roc_auc', 
                        cv = folds, 
                        verbose = 1,
                        return_train_score=True)      

# fit the model
model_cv.fit(X_train_adasyn, y_train_adasyn)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=2,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=200,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              param_grid={'learning_rate': [0.2, 0.6],
#                          'subsample': [0.3, 0.6, 0.9]},
#              return_train_score=True, scoring='roc_auc', verbose=1)

# %%
# cv results
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.668473      0.013963         0.035506        0.001163
# 1       0.680336      0.012902         0.034392        0.000691
# 2       0.617626      0.016726         0.034435        0.001772
# 3       0.648741      0.016707         0.034490        0.001256
# 4       0.660563      0.008260         0.035266        0.001704
# 5       0.630970      0.013081         0.034804        0.001274
#
#   param_learning_rate param_subsample  \
# 0                 0.2             0.3
# 1                 0.2             0.6
# 2                 0.2             0.9
# 3                 0.6             0.3
# 4                 0.6             0.6
# 5                 0.6             0.9
#
#                                      params  split0_test_score  \
# 0  {'learning_rate': 0.2, 'subsample': 0.3}           0.993069
# 1  {'learning_rate': 0.2, 'subsample': 0.6}           0.992996
# 2  {'learning_rate': 0.2, 'subsample': 0.9}           0.991209
# 3  {'learning_rate': 0.6, 'subsample': 0.3}           0.993245
# 4  {'learning_rate': 0.6, 'subsample': 0.6}           0.988765
# 5  {'learning_rate': 0.6, 'subsample': 0.9}           0.991954
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           0.973895           0.982416         0.983126        0.007844
# 1           0.978796           0.983006         0.984933        0.005955
# 2           0.979109           0.982608         0.984309        0.005084
# 3           0.983393           0.986213         0.987617        0.004143
# 4           0.981977           0.983889         0.984877        0.002858
# 5           0.977904           0.989933         0.986597        0.006202
#
#    rank_test_score  split0_train_score  split1_train_score  \
# 0                6            0.999345            0.999395
# 1                3            0.999376            0.999457
# 2                5            0.999230            0.999392
# 3                1            0.999956            0.999964
# 4                4            0.999955            0.999967
# 5                2            0.999961            0.999968
#
#    split2_train_score  mean_train_score  std_train_score
# 0            0.999451          0.999397         0.000044
# 1            0.999469          0.999434         0.000041
# 2            0.999476          0.999366         0.000102
# 3            0.999961          0.999960         0.000003
# 4            0.999968          0.999963         0.000006
# 5            0.999975          0.999968         0.000006

# %%
# # plotting
plt.figure(figsize=(16,6))

param_grid = {'learning_rate': [0.2, 0.6], 
             'subsample': [0.3, 0.6, 0.9]} 


for n, subsample in enumerate(param_grid['subsample']):
    

    # subplot 1/n
    plt.subplot(1,len(param_grid['subsample']), n+1)
    df = cv_results[cv_results['param_subsample']==subsample]

    plt.plot(df["param_learning_rate"], df["mean_test_score"])
    plt.plot(df["param_learning_rate"], df["mean_train_score"])
    plt.xlabel('learning_rate')
    plt.ylabel('AUC')
    plt.title("subsample={0}".format(subsample))
    plt.ylim([0.60, 1])
    plt.legend(['test score', 'train score'], loc='best')
    plt.xscale('log')

# %%
model_cv.best_params_
# Out:
# {'learning_rate': 0.6, 'subsample': 0.3}

# %%
# chosen hyperparameters

params = {'learning_rate': 0.6,
          'max_depth': 2, 
          'n_estimators':200,
          'subsample':0.3,
         'objective':'binary:logistic'}

# fit model on training data
xgb_bal_adasyn_model = XGBClassifier(params = params)
xgb_bal_adasyn_model.fit(X_train_adasyn, y_train_adasyn)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# **Prediction on the train set**

# %%
# Predictions on the train set
y_train_pred = xgb_bal_adasyn_model.predict(X_train_adasyn)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_adasyn, y_train_adasyn)
print(confusion)
# Out:
# [[199020      0]
#  [     0 199035]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_adasyn, y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 1.0
# Sensitivity:- 1.0
# Specificity:- 1.0

# %%
# classification_report
print(classification_report(y_train_adasyn, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    199020
#            1       1.00      1.00      1.00    199035
#
#     accuracy                           1.00    398055
#    macro avg       1.00      1.00      1.00    398055
# weighted avg       1.00      1.00      1.00    398055

# %%
# Predicted probability
y_train_pred_proba = xgb_bal_adasyn_model.predict_proba(X_train_adasyn)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train_adasyn, y_train_pred_proba)
auc
# Out:
# 1.0

# %%
# Plot the ROC curve
draw_roc(y_train_adasyn, y_train_pred_proba)

# %% [markdown]
# **Prediction on the test set**

# %%
# Predictions on the test set
y_test_pred = xgb_bal_adasyn_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[85253    42]
#  [   28   120]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.9991807403766253
# Sensitivity:- 0.8108108108108109
# Specificity:- 0.9995075913007796

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85295
#            1       0.74      0.81      0.77       148
#
#     accuracy                           1.00     85443
#    macro avg       0.87      0.91      0.89     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
# Predicted probability
y_test_pred_proba = xgb_bal_adasyn_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9701724777124859

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# **Model summary** **(xGBoost with Adasyn)**
#
# **Train set**
# - Accuracy = 1
# - Sensitivity = 1
# - Specificity = 1
# - ROC-AUC = 1
#
# **Test set**
# - Accuracy = 1
# - Sensitivity = 0.81
# - Specificity = 1
# - ROC-AUC = 0.97

# %% [markdown]
# # **Decision Tree**

# %%
# Create the parameter grid 
param_grid = {
    'max_depth': range(5, 15, 5),
    'min_samples_leaf': range(50, 150, 50),
    'min_samples_split': range(50, 150, 50),
}


# Instantiate the grid search model
dtree = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator = dtree, 
                           param_grid = param_grid, 
                           scoring= 'roc_auc',
                           cv = 3, 
                           verbose = 1)

# Fit the grid search to the data
grid_search.fit(X_train_adasyn,y_train_adasyn)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': range(5, 15, 5),
#                          'min_samples_leaf': range(50, 150, 50),
#                          'min_samples_split': range(50, 150, 50)},
#              scoring='roc_auc', verbose=1)

# %%
# cv results
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       3.658526      0.032001         0.020674        0.000448
# 1       3.582896      0.027666         0.019441        0.000601
# 2       3.632184      0.041447         0.019588        0.000201
# 3       3.658882      0.017704         0.020280        0.001591
# 4       5.948390      0.165444         0.020167        0.001783
# 5       6.022193      0.217777         0.019777        0.000762
# 6       5.978766      0.194634         0.019518        0.002239
# 7       6.030333      0.156669         0.019665        0.001291
#
#   param_max_depth param_min_samples_leaf param_min_samples_split  \
# 0               5                     50                      50
# 1               5                     50                     100
# 2               5                    100                      50
# 3               5                    100                     100
# 4              10                     50                      50
# 5              10                     50                     100
# 6              10                    100                      50
# 7              10                    100                     100
#
#                                               params  split0_test_score  \
# 0  {'max_depth': 5, 'min_samples_leaf': 50, 'min_...           0.933534
# 1  {'max_depth': 5, 'min_samples_leaf': 50, 'min_...           0.933534
# 2  {'max_depth': 5, 'min_samples_leaf': 100, 'min...           0.933571
# 3  {'max_depth': 5, 'min_samples_leaf': 100, 'min...           0.928213
# 4  {'max_depth': 10, 'min_samples_leaf': 50, 'min...           0.924781
# 5  {'max_depth': 10, 'min_samples_leaf': 50, 'min...           0.924245
# 6  {'max_depth': 10, 'min_samples_leaf': 100, 'mi...           0.931668
# 7  {'max_depth': 10, 'min_samples_leaf': 100, 'mi...           0.930776
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           0.926690           0.932390         0.930871        0.002994
# 1           0.920043           0.932389         0.928656        0.006108
# 2           0.924686           0.932388         0.930215        0.003939
# 3           0.924188           0.932387         0.928262        0.003347
# 4           0.943305           0.920630         0.929572        0.009857
# 5           0.943016           0.923075         0.930112        0.009137
# 6           0.949427           0.925799         0.935631        0.010045
# 7           0.944999           0.927920         0.934565        0.007470
#
#    rank_test_score
# 0                3
# 1                7
# 2                4
# 3                8
# 4                6
# 5                5
# 6                1
# 7                2

# %%
grid_search.best_score_
# Out:
# 0.9356312685493761

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=100, min_samples_split=50)

# %%
# Model with optimal hyperparameters
dt_bal_adasyn_model = DecisionTreeClassifier(criterion = "gini", 
                                  random_state = 100,
                                  max_depth=10, 
                                  min_samples_leaf=100,
                                  min_samples_split=50)

dt_bal_adasyn_model.fit(X_train_adasyn, y_train_adasyn)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=100, min_samples_split=50,
#                        random_state=100)

# %% [markdown]
# **Prediction on the train set**

# %%
# Predictions on the train set
y_train_pred = dt_bal_adasyn_model.predict(X_train_adasyn)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_train_adasyn, y_train_pred)
print(confusion)
# Out:
# [[191468   7552]
#  [  1262 197773]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_train_adasyn, y_train_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.9778573312733165
# Sensitivity:- 0.9936594066370237
# Specificity:- 0.9620540649180986

# %%
# classification_report
print(classification_report(y_train_adasyn, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98    199020
#            1       0.96      0.99      0.98    199035
#
#     accuracy                           0.98    398055
#    macro avg       0.98      0.98      0.98    398055
# weighted avg       0.98      0.98      0.98    398055

# %%
# Predicted probability
y_train_pred_proba = dt_bal_adasyn_model.predict_proba(X_train_adasyn)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_train_adasyn, y_train_pred_proba)
auc
# Out:
# 0.993085516599605

# %%
# Plot the ROC curve
draw_roc(y_train_adasyn, y_train_pred_proba)

# %% [markdown]
# **Prediction on the test set**

# %%
# Predictions on the test set
y_test_pred = dt_bal_adasyn_model.predict(X_test)

# %%
# Confusion matrix
confusion = metrics.confusion_matrix(y_test, y_test_pred)
print(confusion)
# Out:
# [[81966  3329]
#  [   24   124]]

# %%
TP = confusion[1,1] # true positive 
TN = confusion[0,0] # true negatives
FP = confusion[0,1] # false positives
FN = confusion[1,0] # false negatives

# %%
# Accuracy
print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

# Sensitivity
print("Sensitivity:-",TP / float(TP+FN))

# Specificity
print("Specificity:-", TN / float(TN+FP))
# Out:
# Accuracy:- 0.9607574640403543
# Sensitivity:- 0.8378378378378378
# Specificity:- 0.960970748578463

# %%
# classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     85295
#            1       0.04      0.84      0.07       148
#
#     accuracy                           0.96     85443
#    macro avg       0.52      0.90      0.52     85443
# weighted avg       1.00      0.96      0.98     85443

# %%
# Predicted probability
y_test_pred_proba = dt_bal_adasyn_model.predict_proba(X_test)[:,1]

# %%
# roc_auc
auc = metrics.roc_auc_score(y_test, y_test_pred_proba)
auc
# Out:
# 0.9273043633938176

# %%
# Plot the ROC curve
draw_roc(y_test, y_test_pred_proba)

# %% [markdown]
# **Model summary** **(Decision Tree with Adasyn)**
#
# **Train set**
# - Accuracy = 0.98
# - Sensitivity = 0.99
# - Specificity = 0.96
# - ROC-AUC = 0.99
#
# **Test set**
# - Accuracy = 0.96
# - Sensitivity = 0.84
# - Specificity = 0.96
# - ROC-AUC = 0.93

# %% [markdown]
# **Choosing best model on the balanced data**
#
# - Here we balanced the data with two of the best approaches we have SMOTE and Adasyn. With every data balancing thechnique we built several models such as **Logistic**, **XGBoost**, **Decision Tree**, and **Random Forest**.
#
# - SMOTE and Adasyn models performed well. Among those models, the simplist model Logistic regression has **ROC score** **0.99** in the **train set** and **0.97** on the **test set**.
#
# - We can consider the Logistic model as the best model to choose because of the easy interpretation of the models and also the resourse requirements to build the mdoel is lesser than the other heavy models such as Random forest or XGBoost.
#
# - Hence, we can conclude that the **Logistic regression model with SMOTE** is the best model for its simplicity and less resource requirement.

# %% [markdown]
# **Print the FPR,TPR & select the best threshold from the roc curve for the best model**

# %%
print('Train auc =', metrics.roc_auc_score(y_train_smote, y_train_pred_proba_log_bal_smote))
fpr, tpr, thresholds = metrics.roc_curve(y_train_smote, y_train_pred_proba_log_bal_smote)
threshold = thresholds[np.argmax(tpr-fpr)]
print("Threshold=",threshold)
# Out:
# Train auc = 0.9923417783896191
# Threshold= 0.39778789071401716

# %% [markdown]
# We can see that the **threshold** is **0.40**, for which the TPR is the highest and FPR is the lowest and we got the best ROC score.

# %% [markdown]
# ## **Cost-Benefit Analysis**
#
# - We have tried several models with both **balanced** and **imbalanced** data.
#   Most of the models have performed reasonably well in terms of **ROC score, Precision, and Recall**.
#
# - While selecting the **best model**, we must consider factors such as:
#   - Availability of **infrastructure** and **resources**
#   - Required **computational power** to train and deploy the model
#
# - **Complex models** such as **Random Forest, SVM, and XGBoost** require heavy computational resources.
#   Building and maintaining such infrastructure increases the **deployment cost**.
#
# - **Simpler models** such as **Logistic Regression** require fewer resources, making them more cost-effective.
#
# - A critical factor is the **trade-off between model performance and cost**.
#   - If a small improvement in **ROC score** leads to **significant monetary gain or loss** (e.g., in banking or fraud detection), it may justify using a **complex model**, despite its higher computational cost.

# %% [markdown]
# # **Summary to the Business**
#
# - For banks with **smaller average transaction value**, we should focus on achieving **high Precision**.
#   - Rationale: We only want to label relevant transactions as fraudulent.
#   - Each flagged transaction can be verified by involving the **human element** (e.g., calling the customer).
#   - However, if precision is **low**, this leads to many **false positives**, which increase the operational burden on humans.
#
# - For banks with **larger average transaction value**, the focus shifts to **high Recall**.
#   - Rationale: If recall is **low**, the model fails to detect many actual fraudulent transactions (**false negatives**).
#   - In such cases, the potential **loss from missing a high-value fraudulent transaction** can be very significant.
#
# - Therefore, for **high-value transactions**, the bank should prioritize **high Recall** in order to minimize undetected fraud.
#
# - After evaluating several models, we observed that with the **SMOTE-balanced dataset**,
#   **Logistic Regression** achieved:
#   - A strong **ROC score**
#   - High **Recall**
#   - Easy **interpretability** and **explainability** for business stakeholders
#
# ✅ **Conclusion**: Logistic Regression with SMOTE is a strong candidate for deployment as it balances performance with simplicity and interpretability.
